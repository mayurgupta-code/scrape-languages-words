# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
import os

# %%
os.get_exec_path()
# Out:
# ['/opt/anaconda3/bin',
#  '/opt/anaconda3/condabin',
#  '/usr/local/bin',
#  '/usr/bin',
#  '/bin',
#  '/usr/sbin',
#  '/sbin']

# %%
sample = driver.find_element_by_xpath('//*[@id="post-83"]/div/div/table/tbody')

# %%
sample.text
# Out:
# 'Number Dutch in English\n1 als as\n2 I I\n3 zijn his\n4 dat that\n5 hij he\n6 was was\n7 voor for\n8 op on\n9 zijn are\n10 met with\n11 ze they\n12 zijn be\n13 bij at\n14 een one\n15 hebben have\n16 deze this\n17 van from\n18 door by\n19 heet hot\n20 woord word\n21 maar but\n22 wat what\n23 sommige some\n24 is is\n25 het it\n26 u you\n27 of or\n28 had had\n29 de the\n30 van of\n31 aan to\n32 en and\n33 een a\n34 in in\n35 we we\n36 kan can\n37 uit out\n38 andere other\n39 waren were\n40 die which\n41 doen do\n42 hun their\n43 tijd time\n44 indien if\n45 zal will\n46 hoe how\n47 zei said\n48 een an\n49 elk each\n50 vertellen tell\n51 doet does\n52 set set\n53 drie three\n54 willen want\n55 lucht air\n56 goed well\n57 ook also\n58 spelen play\n59 klein small\n60 end end\n61 zetten put\n62 thuis home\n63 lezen read\n64 de hand hand\n65 poort port\n66 grote large\n67 spell spell\n68 toevoegen add\n69 zelfs even\n70 land land\n71 hier here\n72 moet must\n73 grote big\n74 hoog high\n75 de
# ...

# %%
type(sample.text)
# Out:
# str

# %%
str_1 = sample.text

# %%
str_1
# Out:
# 'Number Dutch in English\n1 als as\n2 I I\n3 zijn his\n4 dat that\n5 hij he\n6 was was\n7 voor for\n8 op on\n9 zijn are\n10 met with\n11 ze they\n12 zijn be\n13 bij at\n14 een one\n15 hebben have\n16 deze this\n17 van from\n18 door by\n19 heet hot\n20 woord word\n21 maar but\n22 wat what\n23 sommige some\n24 is is\n25 het it\n26 u you\n27 of or\n28 had had\n29 de the\n30 van of\n31 aan to\n32 en and\n33 een a\n34 in in\n35 we we\n36 kan can\n37 uit out\n38 andere other\n39 waren were\n40 die which\n41 doen do\n42 hun their\n43 tijd time\n44 indien if\n45 zal will\n46 hoe how\n47 zei said\n48 een an\n49 elk each\n50 vertellen tell\n51 doet does\n52 set set\n53 drie three\n54 willen want\n55 lucht air\n56 goed well\n57 ook also\n58 spelen play\n59 klein small\n60 end end\n61 zetten put\n62 thuis home\n63 lezen read\n64 de hand hand\n65 poort port\n66 grote large\n67 spell spell\n68 toevoegen add\n69 zelfs even\n70 land land\n71 hier here\n72 moet must\n73 grote big\n74 hoog high\n75 de
# ...

# %%
lst = str_1.split(' ')

# %%
lst
# Out:
# ['Number',
#  'Dutch',
#  'in',
#  'English\n1',
#  'als',
#  'as\n2',
#  'I',
#  'I\n3',
#  'zijn',
#  'his\n4',
#  'dat',
#  'that\n5',
#  'hij',
#  'he\n6',
#  'was',
#  'was\n7',
#  'voor',
#  'for\n8',
#  'op',
#  'on\n9',
#  'zijn',
#  'are\n10',
#  'met',
#  'with\n11',
#  'ze',
#  'they\n12',
#  'zijn',
#  'be\n13',
#  'bij',
#  'at\n14',
#  'een',
#  'one\n15',
#  'hebben',
#  'have\n16',
#  'deze',
#  'this\n17',
#  'van',
#  'from\n18',
#  'door',
#  'by\n19',
#  'heet',
#  'hot\n20',
#  'woord',
#  'word\n21',
#  'maar',
#  'but\n22',
#  'wat',
#  'what\n23',
#  'sommige',
#  'some\n24',
#  'is',
#  'is\n25',
#  'het',
#  'it\n26',
#  'u',
#  'you\n27',
#  'of',
#  'or\n28',
#  'had',
#  'had\n29',
#  'de',
#  'the\n30',
#  'van',
#  'of\n31',
#  'aan',
#  'to\n32',
#  'en',
#  'and\n33',
#  'een',
#  'a\n34',
#  'in',
#  'in\n35',
#  'we',
#  'we\n36',
#  'kan',
#  'can\n37',
#  'uit',
#  'out\n38',
#  'andere',
#  'other\n39',
#  'waren',
#  'were\n40',
#  'die',
# ...

# %%
driver2 = webdriver.Chrome()

# %%
sample2 = driver2.find_element_by_xpath('//*[@id="post-978"]/div/div[3]/div/p[1]')

# %%
sample2.text
# Out:
# 'Afrikaans\nAlbanian\nAmharic\nArabic\nArmenian\nAzerbaijani\nBasque\nBelarusian\nBengali\nBosnian\nBulgarian\nCatalan\nCebuano\nChichewa\nChinese\nCorsican\nCroatian\nCzech\nDanish\nDutch\nEnglish\nEsperanto\nEstonian\nFilipino\nFinnish\nFrench\nFrisian\nGalician\nGeorgian\nGerman\nGreek\nGujarati\nHaitian\nHausa\nHawaiian\nHebrew\nHindi\nHmong\nHungarian\nIcelandic\nIgbo\nIndonesian\nIrish\nItalian\nJapanese\nJavanese\nKannada\nKazakh\nKhmer\nKinyarwanda\nKorean\nKurdish\nKyrgyz\nLao\nLatin\nLatvian\nLithuanian\nLuxembourgish\nMacedonian\nMalagasy\nMalaysian\nMalayalam\nMaltese\nMaori\nMarathi\nMongolian\nMyanmar (Burmese)\nNepali\nNorwegian\nOdia (Oriya)\nPashto\nPersian\nPolish\nPortuguese\nPunjabi\nRomanian\nRussian\nSamoan\nScots Gaelic\nSerbian\nSesotho\nShona\nSindhi\nSinhala\nSlovak\nSlovenian\nSomali\nSpanish\nSundanese\nSwahili\nSwedish\nTajik\nTamil\nTatar\nTelugu\nThai\nTurkish\nTurkmen\nUkrainian\nUrdu\nUyghur\nUzbek\nVietnamese\nWelsh\nXhosa\nYiddish\nYoruba\nZulu'

# %%
lang_str = sample2.text

# %%
lang_str
# Out:
# 'Afrikaans\nAlbanian\nAmharic\nArabic\nArmenian\nAzerbaijani\nBasque\nBelarusian\nBengali\nBosnian\nBulgarian\nCatalan\nCebuano\nChichewa\nChinese\nCorsican\nCroatian\nCzech\nDanish\nDutch\nEnglish\nEsperanto\nEstonian\nFilipino\nFinnish\nFrench\nFrisian\nGalician\nGeorgian\nGerman\nGreek\nGujarati\nHaitian\nHausa\nHawaiian\nHebrew\nHindi\nHmong\nHungarian\nIcelandic\nIgbo\nIndonesian\nIrish\nItalian\nJapanese\nJavanese\nKannada\nKazakh\nKhmer\nKinyarwanda\nKorean\nKurdish\nKyrgyz\nLao\nLatin\nLatvian\nLithuanian\nLuxembourgish\nMacedonian\nMalagasy\nMalaysian\nMalayalam\nMaltese\nMaori\nMarathi\nMongolian\nMyanmar (Burmese)\nNepali\nNorwegian\nOdia (Oriya)\nPashto\nPersian\nPolish\nPortuguese\nPunjabi\nRomanian\nRussian\nSamoan\nScots Gaelic\nSerbian\nSesotho\nShona\nSindhi\nSinhala\nSlovak\nSlovenian\nSomali\nSpanish\nSundanese\nSwahili\nSwedish\nTajik\nTamil\nTatar\nTelugu\nThai\nTurkish\nTurkmen\nUkrainian\nUrdu\nUyghur\nUzbek\nVietnamese\nWelsh\nXhosa\nYiddish\nYoruba\nZulu'

# %%
lang_lst = lang_str.split('\n')

# %%
lang_lst
# Out:
# ['Afrikaans',
#  'Albanian',
#  'Amharic',
#  'Arabic',
#  'Armenian',
#  'Azerbaijani',
#  'Basque',
#  'Belarusian',
#  'Bengali',
#  'Bosnian',
#  'Bulgarian',
#  'Catalan',
#  'Cebuano',
#  'Chichewa',
#  'Chinese',
#  'Corsican',
#  'Croatian',
#  'Czech',
#  'Danish',
#  'Dutch',
#  'English',
#  'Esperanto',
#  'Estonian',
#  'Filipino',
#  'Finnish',
#  'French',
#  'Frisian',
#  'Galician',
#  'Georgian',
#  'German',
#  'Greek',
#  'Gujarati',
#  'Haitian',
#  'Hausa',
#  'Hawaiian',
#  'Hebrew',
#  'Hindi',
#  'Hmong',
#  'Hungarian',
#  'Icelandic',
#  'Igbo',
#  'Indonesian',
#  'Irish',
#  'Italian',
#  'Japanese',
#  'Javanese',
#  'Kannada',
#  'Kazakh',
#  'Khmer',
#  'Kinyarwanda',
#  'Korean',
#  'Kurdish',
#  'Kyrgyz',
#  'Lao',
#  'Latin',
#  'Latvian',
#  'Lithuanian',
#  'Luxembourgish',
#  'Macedonian',
#  'Malagasy',
#  'Malaysian',
#  'Malayalam',
#  'Maltese',
#  'Maori',
#  'Marathi',
#  'Mongolian',
#  'Myanmar (Burmese)',
#  'Nepali',
#  'Norwegian',
# ...

# %%
len(lang_lst)
# Out:
# 108

# %% [raw]
# open link with link
# get text from tagname = 'tbody'
# open file with filename
# write whole str_1 in file
# close file
#
# Repeat with different lang of list lang_lst

# %%
file = open('words/dutch_words_raw.txt', 'w')

# %%
file.write(str_1)
# Out:
# 16648

# %%
file.close()

# %%
sample3 = driver2.find_element_by_xpath('//*[@id="post-26"]/div/div/table/tbody')
# //*[@id="post-26"]/div/div/table/tbody

# %%
sample3.text
# Out:
# 'Number Armenian in English\n1 ինչպես as\n2 ես I\n3 նրա his\n4 որ that\n5 նա he\n6 էր was\n7 համար for\n8 – ին on\n9 են are\n10 հետ with\n11 նրանք they\n12 լինել be\n13 ի at\n14 մեկ one\n15 ունենալ have\n16 այս this\n17 – ից from\n18 ի by\n19 տաք hot\n20 բառ word\n21 բայց but\n22 ինչ what\n23 մի քանի some\n24 է is\n25 այն it\n26 դուք you\n27 կամ or\n28 էր had\n29 The the\n30 եւ of\n31 մինչեւ to\n32 իսկ and\n33 ա a\n34 – ին in\n35 մենք we\n36 կարող can\n37 դուրս out\n38 այլ other\n39 են were\n40 որը which\n41 անել do\n42 իրենց their\n43 ժամանակ time\n44 եթե if\n45 կամք will\n46 ինչպես how\n47 ասել said\n48 է an\n49 յուրաքանչյուր each\n50 ասել tell\n51 մենք does\n52 շարք set\n53 երեք three\n54 ուզում want\n55 օդի air\n56 լավ well\n57 նույնպես also\n58 խաղալ play\n59 փոքր small\n60 վերջ end\n61 ի put\n62 տուն home\n63 կարդալ read\n64 ձեռք hand\n65 նավահանգիստ port\n66 մեծ large\n67 տառ առ տառ ասել spell\n68 ավելացնել add\n69 նույնիսկ even\n70 երկիր land\n71 այստեղ here\n72 պետք է must\n
# ...

# %% [raw]
# //*[@id="post-32"]/div/div/table/tbody -1
# //*[@id="post-30"]/div/div/table/tbody -2

# %%
sample4 = driver.find_element_by_tag_name('tbody')

# %%
sample4.text
# Out:
# 'Number Dutch in English\n1 als as\n2 I I\n3 zijn his\n4 dat that\n5 hij he\n6 was was\n7 voor for\n8 op on\n9 zijn are\n10 met with\n11 ze they\n12 zijn be\n13 bij at\n14 een one\n15 hebben have\n16 deze this\n17 van from\n18 door by\n19 heet hot\n20 woord word\n21 maar but\n22 wat what\n23 sommige some\n24 is is\n25 het it\n26 u you\n27 of or\n28 had had\n29 de the\n30 van of\n31 aan to\n32 en and\n33 een a\n34 in in\n35 we we\n36 kan can\n37 uit out\n38 andere other\n39 waren were\n40 die which\n41 doen do\n42 hun their\n43 tijd time\n44 indien if\n45 zal will\n46 hoe how\n47 zei said\n48 een an\n49 elk each\n50 vertellen tell\n51 doet does\n52 set set\n53 drie three\n54 willen want\n55 lucht air\n56 goed well\n57 ook also\n58 spelen play\n59 klein small\n60 end end\n61 zetten put\n62 thuis home\n63 lezen read\n64 de hand hand\n65 poort port\n66 grote large\n67 spell spell\n68 toevoegen add\n69 zelfs even\n70 land land\n71 hier here\n72 moet must\n73 grote big\n74 hoog high\n75 de
# ...

# %%
sample5 = driver2.find_element_by_tag_name('tbody')

# %%
sample5.text
# Out:
# 'Number Albanian in English\n1 si as\n2 I I\n3 e tij his\n4 që that\n5 ai he\n6 ishte was\n7 për for\n8 në on\n9 janë are\n10 me with\n11 ata they\n12 jetë be\n13 në at\n14 një one\n15 kam have\n16 kjo this\n17 nga from\n18 nga by\n19 hot hot\n20 fjalë word\n21 por but\n22 çfarë what\n23 disa some\n24 është is\n25 ajo it\n26 ju you\n27 ose or\n28 kishte had\n29 thonë the\n30 i of\n31 në to\n32 dhe and\n33 një a\n34 në in\n35 ne we\n36 mund can\n37 jashtë out\n38 tjetër other\n39 ishin were\n40 e cila which\n41 bëj do\n42 tyre their\n43 koha time\n44 nëse if\n45 do will\n46 si how\n47 tha said\n48 një an\n49 çdo each\n50 them tell\n51 bën does\n52 i vendosur set\n53 tre three\n54 dua want\n55 ajrit air\n56 mirë well\n57 edhe also\n58 luajnë play\n59 vogël small\n60 fund end\n61 vendos put\n62 shtëpi home\n63 lexoj read\n64 dorë hand\n65 port port\n66 i madh large\n67 magji spell\n68 të shtoni add\n69 edhe even\n70 tokë land\n71 këtu here\n72 duhet must\n73 i madh big\n74 i lartë high\
# ...

# %% [raw]
# open file with filename
# write whole str_1
# close file

# %%
current_lang = 'dutch'
linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'

# %%
linkname
# Out:
# 'https://1000mostcommonwords.com/1000-most-common-dutch-words/'

# %%
driver.get(linkname)

# %%
filename = 'words/'+current_lang+'_words.txt'

# %%
file = open(filename, 'w')
file.close()

# %%
lang_lst
# Out:
# ['Afrikaans',
#  'Albanian',
#  'Amharic',
#  'Arabic',
#  'Armenian',
#  'Azerbaijani',
#  'Basque',
#  'Belarusian',
#  'Bengali',
#  'Bosnian',
#  'Bulgarian',
#  'Catalan',
#  'Cebuano',
#  'Chichewa',
#  'Chinese',
#  'Corsican',
#  'Croatian',
#  'Czech',
#  'Danish',
#  'Dutch',
#  'English',
#  'Esperanto',
#  'Estonian',
#  'Filipino',
#  'Finnish',
#  'French',
#  'Frisian',
#  'Galician',
#  'Georgian',
#  'German',
#  'Greek',
#  'Gujarati',
#  'Haitian',
#  'Hausa',
#  'Hawaiian',
#  'Hebrew',
#  'Hindi',
#  'Hmong',
#  'Hungarian',
#  'Icelandic',
#  'Igbo',
#  'Indonesian',
#  'Irish',
#  'Italian',
#  'Japanese',
#  'Javanese',
#  'Kannada',
#  'Kazakh',
#  'Khmer',
#  'Kinyarwanda',
#  'Korean',
#  'Kurdish',
#  'Kyrgyz',
#  'Lao',
#  'Latin',
#  'Latvian',
#  'Lithuanian',
#  'Luxembourgish',
#  'Macedonian',
#  'Malagasy',
#  'Malaysian',
#  'Malayalam',
#  'Maltese',
#  'Maori',
#  'Marathi',
#  'Mongolian',
#  'Myanmar (Burmese)',
#  'Nepali',
#  'Norwegian',
# ...

# %%
for current_lang in lang_lst:
    print('executing for:', current_lang)
# Out:
# executing for: Afrikaans
# executing for: Albanian
# executing for: Amharic
# executing for: Arabic
# executing for: Armenian
# executing for: Azerbaijani
# executing for: Basque
# executing for: Belarusian
# executing for: Bengali
# executing for: Bosnian
# executing for: Bulgarian
# executing for: Catalan
# executing for: Cebuano
# executing for: Chichewa
# executing for: Chinese
# executing for: Corsican
# executing for: Croatian
# executing for: Czech
# executing for: Danish
# executing for: Dutch
# executing for: English
# executing for: Esperanto
# executing for: Estonian
# executing for: Filipino
# executing for: Finnish
# executing for: French
# executing for: Frisian
# executing for: Galician
# executing for: Georgian
# executing for: German
# executing for: Greek
# executing for: Gujarati
# executing for: Haitian
# executing for: Hausa
# executing for: Hawaiian
# executing for: Hebrew
# executing for: Hindi
# executing for: Hmong
# executing for: Hungarian
# ...

# %%
import time
print('going to sleep!')
time.sleep(5)
print('waked up!')
# Out:
# going to sleep!
# waked up!

# %%
for i in range(3,7):
    current_lang = lang_lst[i]
    print('executing for:', current_lang)  
    linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'
    driver.get(linkname)
    time.sleep(1)
    #time.sleep(5)
    
    print('finding element...')
    sample = driver.find_element_by_tag_name('tbody')   
    words_raw = sample.text
    
    print('opening file...')
    filename = 'words/'+current_lang+'_words.txt' 
    print('writing file...')
    file = open(filename, 'w')
    file.write(words_raw)
    file.close()
    print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# executing for: Arabic
# finding element...
# opening file...
# writing file...
# completed for 4/108 👍🏻
# executing for: Armenian
# finding element...
# opening file...
# writing file...
# completed for 5/108 👍🏻
# executing for: Azerbaijani
# finding element...
# opening file...
# writing file...
# completed for 6/108 👍🏻
# executing for: Basque
# finding element...
# opening file...
# writing file...
# completed for 7/108 👍🏻

# %%
i
# Out:
# 1

# %%
print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# completed for 2/108 👍🏻

# %%
for i in range(7,13):
    current_lang = lang_lst[i]
    print('executing for:', current_lang)  
    linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'
    driver.get(linkname)
    time.sleep(1)
    #time.sleep(5)
    
    print('finding element...')
    sample = driver.find_element_by_tag_name('tbody')   
    words_raw = sample.text
    
    print('opening file...')
    filename = 'words/'+current_lang+'_words.txt' 
    print('writing file...')
    file = open(filename, 'w')
    file.write(words_raw)
    file.close()
    print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# executing for: Belarusian
# finding element...
# opening file...
# writing file...
# completed for 8/108 👍🏻
# executing for: Bengali
# finding element...
# opening file...
# writing file...
# completed for 9/108 👍🏻
# executing for: Bosnian
# finding element...
# opening file...
# writing file...
# completed for 10/108 👍🏻
# executing for: Bulgarian
# finding element...
# opening file...
# writing file...
# completed for 11/108 👍🏻
# executing for: Catalan
# finding element...
# opening file...
# writing file...
# completed for 12/108 👍🏻
# executing for: Cebuano
# finding element...
# opening file...
# writing file...
# completed for 13/108 👍🏻

# %%
for i in range(13,20):
    current_lang = lang_lst[i]
    print('executing for:', current_lang)  
    linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'
    driver.get(linkname)
    time.sleep(1)
    #time.sleep(5)
    
    print('finding element...')
    sample = driver.find_element_by_tag_name('tbody')   
    words_raw = sample.text
    
    print('opening file...')
    filename = 'words/'+current_lang+'_words.txt' 
    print('writing file...')
    file = open(filename, 'w')
    file.write(words_raw)
    file.close()
    print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# executing for: Chichewa
# finding element...
# opening file...
# writing file...
# completed for 14/108 👍🏻
# executing for: Chinese
# finding element...
# opening file...
# writing file...
# completed for 15/108 👍🏻
# executing for: Corsican
# finding element...
# opening file...
# writing file...
# completed for 16/108 👍🏻
# executing for: Croatian
# finding element...
# opening file...
# writing file...
# completed for 17/108 👍🏻
# executing for: Czech
# finding element...
# opening file...
# writing file...
# completed for 18/108 👍🏻
# executing for: Danish
# finding element...
# opening file...
# writing file...
# completed for 19/108 👍🏻
# executing for: Dutch
# finding element...
# opening file...
# writing file...
# completed for 20/108 👍🏻

# %%
for i in range(20,30):
    current_lang = lang_lst[i]
    print('executing for:', current_lang)  
    linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'
    driver.get(linkname)
    time.sleep(1)
    #time.sleep(5)
    
    print('finding element...')
    sample = driver.find_element_by_tag_name('tbody')   
    words_raw = sample.text
    
    print('opening file...')
    filename = 'words/'+current_lang+'_words.txt' 
    print('writing file...')
    file = open(filename, 'w')
    file.write(words_raw)
    file.close()
    print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# executing for: English
# finding element...
# opening file...
# writing file...
# completed for 21/108 👍🏻
# executing for: Esperanto
# finding element...
# opening file...
# writing file...
# completed for 22/108 👍🏻
# executing for: Estonian
# finding element...
# opening file...
# writing file...
# completed for 23/108 👍🏻
# executing for: Filipino
# finding element...
# opening file...
# writing file...
# completed for 24/108 👍🏻
# executing for: Finnish
# finding element...
# opening file...
# writing file...
# completed for 25/108 👍🏻
# executing for: French
# finding element...
# opening file...
# writing file...
# completed for 26/108 👍🏻
# executing for: Frisian
# finding element...
# opening file...
# writing file...
# completed for 27/108 👍🏻
# executing for: Galician
# finding element...
# opening file...
# writing file...
# completed for 28/108 👍🏻
# executing for: Georgian
# finding element...
# opening file...
# writing file...
# completed for 29/108 👍🏻
# ...

# %%
for i in range(45, 65):
    current_lang = lang_lst[i]
    print('executing for:', current_lang)  
    linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'
    driver.get(linkname)
    time.sleep(1)
    #time.sleep(5)
    
    print('finding element...')
    sample = driver.find_element_by_tag_name('tbody')   
    words_raw = sample.text
    
    print('opening file...')
    filename = 'words/'+current_lang+'_words.txt' 
    print('writing file...')
    file = open(filename, 'w')
    file.write(words_raw)
    file.close()
    print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# executing for: Javanese
# finding element...
# opening file...
# writing file...
# completed for 46/108 👍🏻
# executing for: Kannada
# finding element...
# opening file...
# writing file...
# completed for 47/108 👍🏻
# executing for: Kazakh
# finding element...
# opening file...
# writing file...
# completed for 48/108 👍🏻
# executing for: Khmer
# finding element...
# opening file...
# writing file...
# completed for 49/108 👍🏻
# executing for: Kinyarwanda
# finding element...
# opening file...
# writing file...
# completed for 50/108 👍🏻
# executing for: Korean
# finding element...
# opening file...
# writing file...
# completed for 51/108 👍🏻
# executing for: Kurdish
# finding element...
# opening file...
# writing file...
# completed for 52/108 👍🏻
# executing for: Kyrgyz
# finding element...
# opening file...
# writing file...
# completed for 53/108 👍🏻
# executing for: Lao
# finding element...
# opening file...
# writing file...
# completed for 54/108 👍🏻
# executing for: Latin
# ...

# %% [raw]
# error raised for
# Myanmar (Burmese)
# Odia (Oriya)
# Scots Gaelic

# %%
for i in range(94, 108):
    current_lang = lang_lst[i]
    print('executing for:', current_lang)  
    linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'
    driver.get(linkname)
    time.sleep(1)
    #time.sleep(5)
    
    print('finding element...')
    sample = driver.find_element_by_tag_name('tbody')   
    words_raw = sample.text
    
    print('opening file...')
    filename = 'words/'+current_lang+'_words.txt' 
    print('writing file...')
    file = open(filename, 'w')
    file.write(words_raw)
    file.close()
    print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# executing for: Telugu
# finding element...
# opening file...
# writing file...
# completed for 95/108 👍🏻
# executing for: Thai
# finding element...
# opening file...
# writing file...
# completed for 96/108 👍🏻
# executing for: Turkish
# finding element...
# opening file...
# writing file...
# completed for 97/108 👍🏻
# executing for: Turkmen
# finding element...
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-102-f45439acbe5b> in <module>
#       8
#       9     print('finding element...')
# ---> 10     sample = driver.find_element_by_tag_name('tbody')
#      11     words_raw = sample.text
#      12
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_tag_name(self, name)
#     528             element = driver.find_element_by_tag_name('h1')
#     529         """
# ...

# %%
lang_lst[93]
# Out:
# 'Tatar'

# %%
len(lang_lst)
# Out:
# 108

# %%
#this one is best one
for i in range(97, 99):
    current_lang = lang_lst[i]
    print('executing for:', current_lang)  
    linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'
    driver.get(linkname)
    time.sleep(1)
    #time.sleep(5)
    
    try:
        print('finding element...')
        sample = driver.find_element_by_tag_name('tbody')   
        words_raw = sample.text
    except:
        continue
    
    print('opening file...')
    filename = 'words/'+current_lang+'_words.txt' 
    print('writing file...')
    file = open(filename, 'w')
    file.write(words_raw)
    file.close()
    print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# executing for: Turkmen
# finding element...
# executing for: Ukrainian
# finding element...
# opening file...
# writing file...
# completed for 99/108 👍🏻

# %%
for i in range(103, 108):
    current_lang = lang_lst[i]
    print('executing for:', current_lang)  
    linkname = 'https://1000mostcommonwords.com/1000-most-common-'+current_lang+'-words/'
    driver.get(linkname)
    time.sleep(1)
    #time.sleep(5)
    
    try:
        print('finding element...')
        sample = driver.find_element_by_tag_name('tbody')   
        words_raw = sample.text
    except:
        continue
    
    print('opening file...')
    filename = 'words/'+current_lang+'_words.txt' 
    print('writing file...')
    file = open(filename, 'w')
    file.write(words_raw)
    file.close()
    print('completed for {}/108 👍🏻'.format(i+1))
# Out:
# executing for: Welsh
# finding element...
# opening file...
# writing file...
# completed for 104/108 👍🏻
# executing for: Xhosa
# finding element...
# opening file...
# writing file...
# completed for 105/108 👍🏻
# executing for: Yiddish
# finding element...
# opening file...
# writing file...
# completed for 106/108 👍🏻
# executing for: Yoruba
# finding element...
# opening file...
# writing file...
# completed for 107/108 👍🏻
# executing for: Zulu
# finding element...
# opening file...
# writing file...
# completed for 108/108 👍🏻

# %%
current_lang = 'Scots'
sample = driver.find_element_by_tag_name('tbody')   
words_raw = sample.text

print('opening file...')
filename = 'words/'+current_lang+'_words.txt' 
print('writing file...')
file = open(filename, 'w')
file.write(words_raw)
file.close()
print('done')
# Out:
# opening file...
# writing file...
# done

# %%
lang_lst
# Out:
# ['Afrikaans',
#  'Albanian',
#  'Amharic',
#  'Arabic',
#  'Armenian',
#  'Azerbaijani',
#  'Basque',
#  'Belarusian',
#  'Bengali',
#  'Bosnian',
#  'Bulgarian',
#  'Catalan',
#  'Cebuano',
#  'Chichewa',
#  'Chinese',
#  'Corsican',
#  'Croatian',
#  'Czech',
#  'Danish',
#  'Dutch',
#  'English',
#  'Esperanto',
#  'Estonian',
#  'Filipino',
#  'Finnish',
#  'French',
#  'Frisian',
#  'Galician',
#  'Georgian',
#  'German',
#  'Greek',
#  'Gujarati',
#  'Haitian',
#  'Hausa',
#  'Hawaiian',
#  'Hebrew',
#  'Hindi',
#  'Hmong',
#  'Hungarian',
#  'Icelandic',
#  'Igbo',
#  'Indonesian',
#  'Irish',
#  'Italian',
#  'Japanese',
#  'Javanese',
#  'Kannada',
#  'Kazakh',
#  'Khmer',
#  'Kinyarwanda',
#  'Korean',
#  'Kurdish',
#  'Kyrgyz',
#  'Lao',
#  'Latin',
#  'Latvian',
#  'Lithuanian',
#  'Luxembourgish',
#  'Macedonian',
#  'Malagasy',
#  'Malaysian',
#  'Malayalam',
#  'Maltese',
#  'Maori',
#  'Marathi',
#  'Mongolian',
#  'Myanmar (Burmese)',
#  'Nepali',
#  'Norwegian',
# ...

# %%
lang_str
# Out:
# 'Afrikaans\nAlbanian\nAmharic\nArabic\nArmenian\nAzerbaijani\nBasque\nBelarusian\nBengali\nBosnian\nBulgarian\nCatalan\nCebuano\nChichewa\nChinese\nCorsican\nCroatian\nCzech\nDanish\nDutch\nEnglish\nEsperanto\nEstonian\nFilipino\nFinnish\nFrench\nFrisian\nGalician\nGeorgian\nGerman\nGreek\nGujarati\nHaitian\nHausa\nHawaiian\nHebrew\nHindi\nHmong\nHungarian\nIcelandic\nIgbo\nIndonesian\nIrish\nItalian\nJapanese\nJavanese\nKannada\nKazakh\nKhmer\nKinyarwanda\nKorean\nKurdish\nKyrgyz\nLao\nLatin\nLatvian\nLithuanian\nLuxembourgish\nMacedonian\nMalagasy\nMalaysian\nMalayalam\nMaltese\nMaori\nMarathi\nMongolian\nMyanmar (Burmese)\nNepali\nNorwegian\nOdia (Oriya)\nPashto\nPersian\nPolish\nPortuguese\nPunjabi\nRomanian\nRussian\nSamoan\nScots Gaelic\nSerbian\nSesotho\nShona\nSindhi\nSinhala\nSlovak\nSlovenian\nSomali\nSpanish\nSundanese\nSwahili\nSwedish\nTajik\nTamil\nTatar\nTelugu\nThai\nTurkish\nTurkmen\nUkrainian\nUrdu\nUyghur\nUzbek\nVietnamese\nWelsh\nXhosa\nYiddish\nYoruba\nZulu'

# %%
file = open('lan')
