# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/apple/Desktop/ML/ML Practice'

# %%
file = open('words_copy/Dutch_words.txt')

# %%
str_1 = file.read()

# %%
file.close()

# %%
str_1
# Out:
# 'Number Dutch in English\n1 als as\n2 I I\n3 zijn his\n4 dat that\n5 hij he\n6 was was\n7 voor for\n8 op on\n9 zijn are\n10 met with\n11 ze they\n12 zijn be\n13 bij at\n14 een one\n15 hebben have\n16 deze this\n17 van from\n18 door by\n19 heet hot\n20 woord word\n21 maar but\n22 wat what\n23 sommige some\n24 is is\n25 het it\n26 u you\n27 of or\n28 had had\n29 de the\n30 van of\n31 aan to\n32 en and\n33 een a\n34 in in\n35 we we\n36 kan can\n37 uit out\n38 andere other\n39 waren were\n40 die which\n41 doen do\n42 hun their\n43 tijd time\n44 indien if\n45 zal will\n46 hoe how\n47 zei said\n48 een an\n49 elk each\n50 vertellen tell\n51 doet does\n52 set set\n53 drie three\n54 willen want\n55 lucht air\n56 goed well\n57 ook also\n58 spelen play\n59 klein small\n60 end end\n61 zetten put\n62 thuis home\n63 lezen read\n64 de hand hand\n65 poort port\n66 grote large\n67 spell spell\n68 toevoegen add\n69 zelfs even\n70 land land\n71 hier here\n72 moet must\n73 grote big\n74 hoog high\n75 de
# ...

# %%
lst = str_1.split('\n')

# %%
lst
# Out:
# ['Number Dutch in English',
#  '1 als as',
#  '2 I I',
#  '3 zijn his',
#  '4 dat that',
#  '5 hij he',
#  '6 was was',
#  '7 voor for',
#  '8 op on',
#  '9 zijn are',
#  '10 met with',
#  '11 ze they',
#  '12 zijn be',
#  '13 bij at',
#  '14 een one',
#  '15 hebben have',
#  '16 deze this',
#  '17 van from',
#  '18 door by',
#  '19 heet hot',
#  '20 woord word',
#  '21 maar but',
#  '22 wat what',
#  '23 sommige some',
#  '24 is is',
#  '25 het it',
#  '26 u you',
#  '27 of or',
#  '28 had had',
#  '29 de the',
#  '30 van of',
#  '31 aan to',
#  '32 en and',
#  '33 een a',
#  '34 in in',
#  '35 we we',
#  '36 kan can',
#  '37 uit out',
#  '38 andere other',
#  '39 waren were',
#  '40 die which',
#  '41 doen do',
#  '42 hun their',
#  '43 tijd time',
#  '44 indien if',
#  '45 zal will',
#  '46 hoe how',
#  '47 zei said',
#  '48 een an',
#  '49 elk each',
#  '50 vertellen tell',
#  '51 doet does',
#  '52 set set',
#  '53 drie three',
#  '54 willen want',
#  '55 lucht air',
# ...

# %%
len(str_1)
# Out:
# 16648

# %%
file.closed
# Out:
# True

# %%
file = open('words_copy/Afrikaans_words.txt')

# %%
str_2 = file.read()

# %%
str_2
# Out:
# 'Number Afrikaans in English\n1 as as\n2 Ek I\n3 sy his\n4 wat that\n5 hy he\n6 was was\n7 vir for\n8 op on\n9 is are\n10 met with\n11 hulle they\n12 wees be\n13 op at\n14 een one\n15 het have\n16 hierdie this\n17 uit from\n18 deur by\n19 warm hot\n20 woord word\n21 maar but\n22 wat what\n23 sommige some\n24 is is\n25 dit it\n26 jy you\n27 of or\n28 moes had\n29 die the\n30 van of\n31 te to\n32 en and\n33 ‘n a\n34 in in\n35 ons we\n36 kan can\n37 uit out\n38 ander other\n39 was were\n40 wat which\n41 doen do\n42 hul their\n43 tyd time\n44 indien if\n45 sal will\n46 hoe how\n47 gesê said\n48 ‘n an\n49 elke each\n50 vertel tell\n51 doen does\n52 stel set\n53 drie three\n54 wil want\n55 lug air\n56 goed well\n57 ook also\n58 speel play\n59 klein small\n60 einde end\n61 sit put\n62 huis home\n63 lees read\n64 hand hand\n65 hawe port\n66 groot large\n67 spel spell\n68 voeg add\n69 selfs even\n70 land land\n71 hier here\n72 moet must\n73 groot big\n74 hoë high\n75 sodanige such\n76 volg fo
# ...

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
len(str_2)
# Out:
# 15928

# %%
lst
# Out:
# ['Number Dutch in English',
#  '1 als as',
#  '2 I I',
#  '3 zijn his',
#  '4 dat that',
#  '5 hij he',
#  '6 was was',
#  '7 voor for',
#  '8 op on',
#  '9 zijn are',
#  '10 met with',
#  '11 ze they',
#  '12 zijn be',
#  '13 bij at',
#  '14 een one',
#  '15 hebben have',
#  '16 deze this',
#  '17 van from',
#  '18 door by',
#  '19 heet hot',
#  '20 woord word',
#  '21 maar but',
#  '22 wat what',
#  '23 sommige some',
#  '24 is is',
#  '25 het it',
#  '26 u you',
#  '27 of or',
#  '28 had had',
#  '29 de the',
#  '30 van of',
#  '31 aan to',
#  '32 en and',
#  '33 een a',
#  '34 in in',
#  '35 we we',
#  '36 kan can',
#  '37 uit out',
#  '38 andere other',
#  '39 waren were',
#  '40 die which',
#  '41 doen do',
#  '42 hun their',
#  '43 tijd time',
#  '44 indien if',
#  '45 zal will',
#  '46 hoe how',
#  '47 zei said',
#  '48 een an',
#  '49 elk each',
#  '50 vertellen tell',
#  '51 doet does',
#  '52 set set',
#  '53 drie three',
#  '54 willen want',
#  '55 lucht air',
# ...

# %%
lst.pop(0)
# Out:
# 'Number Dutch in English'

# %%
lst
# Out:
# ['1 als as',
#  '2 I I',
#  '3 zijn his',
#  '4 dat that',
#  '5 hij he',
#  '6 was was',
#  '7 voor for',
#  '8 op on',
#  '9 zijn are',
#  '10 met with',
#  '11 ze they',
#  '12 zijn be',
#  '13 bij at',
#  '14 een one',
#  '15 hebben have',
#  '16 deze this',
#  '17 van from',
#  '18 door by',
#  '19 heet hot',
#  '20 woord word',
#  '21 maar but',
#  '22 wat what',
#  '23 sommige some',
#  '24 is is',
#  '25 het it',
#  '26 u you',
#  '27 of or',
#  '28 had had',
#  '29 de the',
#  '30 van of',
#  '31 aan to',
#  '32 en and',
#  '33 een a',
#  '34 in in',
#  '35 we we',
#  '36 kan can',
#  '37 uit out',
#  '38 andere other',
#  '39 waren were',
#  '40 die which',
#  '41 doen do',
#  '42 hun their',
#  '43 tijd time',
#  '44 indien if',
#  '45 zal will',
#  '46 hoe how',
#  '47 zei said',
#  '48 een an',
#  '49 elk each',
#  '50 vertellen tell',
#  '51 doet does',
#  '52 set set',
#  '53 drie three',
#  '54 willen want',
#  '55 lucht air',
#  '56 goed well',
#  '57 ook also',
# ...

# %%
str_3 = ' '.join(lst)

# %%
str_3
# Out:
# '1 als as 2 I I 3 zijn his 4 dat that 5 hij he 6 was was 7 voor for 8 op on 9 zijn are 10 met with 11 ze they 12 zijn be 13 bij at 14 een one 15 hebben have 16 deze this 17 van from 18 door by 19 heet hot 20 woord word 21 maar but 22 wat what 23 sommige some 24 is is 25 het it 26 u you 27 of or 28 had had 29 de the 30 van of 31 aan to 32 en and 33 een a 34 in in 35 we we 36 kan can 37 uit out 38 andere other 39 waren were 40 die which 41 doen do 42 hun their 43 tijd time 44 indien if 45 zal will 46 hoe how 47 zei said 48 een an 49 elk each 50 vertellen tell 51 doet does 52 set set 53 drie three 54 willen want 55 lucht air 56 goed well 57 ook also 58 spelen play 59 klein small 60 end end 61 zetten put 62 thuis home 63 lezen read 64 de hand hand 65 poort port 66 grote large 67 spell spell 68 toevoegen add 69 zelfs even 70 land land 71 hier here 72 moet must 73 grote big 74 hoog high 75 dergelijke such 76 volgen follow 77 act act 78 waarom why 79 vragen ask 80 mannen men 81 verandering 
# ...

# %%
lst_2 = str_3.split(' ')

# %%
lst_2
# Out:
# ['1',
#  'als',
#  'as',
#  '2',
#  'I',
#  'I',
#  '3',
#  'zijn',
#  'his',
#  '4',
#  'dat',
#  'that',
#  '5',
#  'hij',
#  'he',
#  '6',
#  'was',
#  'was',
#  '7',
#  'voor',
#  'for',
#  '8',
#  'op',
#  'on',
#  '9',
#  'zijn',
#  'are',
#  '10',
#  'met',
#  'with',
#  '11',
#  'ze',
#  'they',
#  '12',
#  'zijn',
#  'be',
#  '13',
#  'bij',
#  'at',
#  '14',
#  'een',
#  'one',
#  '15',
#  'hebben',
#  'have',
#  '16',
#  'deze',
#  'this',
#  '17',
#  'van',
#  'from',
#  '18',
#  'door',
#  'by',
#  '19',
#  'heet',
#  'hot',
#  '20',
#  'woord',
#  'word',
#  '21',
#  'maar',
#  'but',
#  '22',
#  'wat',
#  'what',
#  '23',
#  'sommige',
#  'some',
#  '24',
#  'is',
#  'is',
#  '25',
#  'het',
#  'it',
#  '26',
#  'u',
#  'you',
#  '27',
#  'of',
#  'or',
#  '28',
#  'had',
#  'had',
#  '29',
#  'de',
#  'the',
#  '30',
#  'van',
#  'of',
#  '31',
#  'aan',
#  'to',
#  '32',
#  'en',
#  'and',
#  '33',
#  'een',
#  'a',
#  '34',
#  'in',
#  'in',
#  '35',
#  'we',
# ...

# %% [raw]
# 1 4 7 10

# %%
ranges = list(range(1, 11, 3))
ranges
# Out:
# [1, 4, 7, 10]

# %%
len(lst_2)
# Out:
# 3018

# %%
words_lst = []
for i in range(1, 3018, 3):
    words_lst.append(lst_2[i])

# %%
words_lst
# Out:
# ['als',
#  'I',
#  'zijn',
#  'dat',
#  'hij',
#  'was',
#  'voor',
#  'op',
#  'zijn',
#  'met',
#  'ze',
#  'zijn',
#  'bij',
#  'een',
#  'hebben',
#  'deze',
#  'van',
#  'door',
#  'heet',
#  'woord',
#  'maar',
#  'wat',
#  'sommige',
#  'is',
#  'het',
#  'u',
#  'of',
#  'had',
#  'de',
#  'van',
#  'aan',
#  'en',
#  'een',
#  'in',
#  'we',
#  'kan',
#  'uit',
#  'andere',
#  'waren',
#  'die',
#  'doen',
#  'hun',
#  'tijd',
#  'indien',
#  'zal',
#  'hoe',
#  'zei',
#  'een',
#  'elk',
#  'vertellen',
#  'doet',
#  'set',
#  'drie',
#  'willen',
#  'lucht',
#  'goed',
#  'ook',
#  'spelen',
#  'klein',
#  'end',
#  'zetten',
#  'thuis',
#  'lezen',
#  'de',
#  '65',
#  '66',
#  '67',
#  '68',
#  '69',
#  '70',
#  '71',
#  '72',
#  '73',
#  '74',
#  '75',
#  '76',
#  '77',
#  '78',
#  '79',
#  '80',
#  '81',
#  '82',
#  '83',
#  '84',
#  '85',
#  '86',
#  'need',
#  'house',
#  'picture',
#  'try',
#  'us',
#  'again',
#  'animal',
#  'point',
#  'mother',
#  'world',
# ...

# %%
len(words_lst)
# Out:
# 1006

# %%
words_lst = []
for i in range(0, len(lst_2))

# %%
import pandas as pd

# %%
df = pd.read_csv('words_copy/Dutch_words.txt', delimiter='\n', index_col=False)

# %%
df
# Out:
#        Number Dutch in English
# 0                     1 als as
# 1                        2 I I
# 2                   3 zijn his
# 3                   4 dat that
# 4                     5 hij he
# ..                         ...
# 995              996 neus nose
# 996        997 meervoud plural
# 997            998 woede anger
# 998        999 vordering claim
# 999  1000 werelddeel continent
#
# [1000 rows x 1 columns]

# %%
df.head()
# Out:
#   Number Dutch in English
# 0                1 als as
# 1                   2 I I
# 2              3 zijn his
# 3              4 dat that
# 4                5 hij he

# %%
df.iloc[:, :2]
# Out:
#        Number Dutch in English
# 0                     1 als as
# 1                        2 I I
# 2                   3 zijn his
# 3                   4 dat that
# 4                     5 hij he
# ..                         ...
# 995              996 neus nose
# 996        997 meervoud plural
# 997            998 woede anger
# 998        999 vordering claim
# 999  1000 werelddeel continent
#
# [1000 rows x 1 columns]

# %%
lst
# Out:
# ['1 als as',
#  '2 I I',
#  '3 zijn his',
#  '4 dat that',
#  '5 hij he',
#  '6 was was',
#  '7 voor for',
#  '8 op on',
#  '9 zijn are',
#  '10 met with',
#  '11 ze they',
#  '12 zijn be',
#  '13 bij at',
#  '14 een one',
#  '15 hebben have',
#  '16 deze this',
#  '17 van from',
#  '18 door by',
#  '19 heet hot',
#  '20 woord word',
#  '21 maar but',
#  '22 wat what',
#  '23 sommige some',
#  '24 is is',
#  '25 het it',
#  '26 u you',
#  '27 of or',
#  '28 had had',
#  '29 de the',
#  '30 van of',
#  '31 aan to',
#  '32 en and',
#  '33 een a',
#  '34 in in',
#  '35 we we',
#  '36 kan can',
#  '37 uit out',
#  '38 andere other',
#  '39 waren were',
#  '40 die which',
#  '41 doen do',
#  '42 hun their',
#  '43 tijd time',
#  '44 indien if',
#  '45 zal will',
#  '46 hoe how',
#  '47 zei said',
#  '48 een an',
#  '49 elk each',
#  '50 vertellen tell',
#  '51 doet does',
#  '52 set set',
#  '53 drie three',
#  '54 willen want',
#  '55 lucht air',
#  '56 goed well',
#  '57 ook also',
# ...

# %%
lst_z = ['a', 'b', 'c', 'd', 'e']

# %%
lst_z.remove('b')

# %%
lst_z
# Out:
# ['a', 'c', 'd', 'e']

# %%
str_z = 'hello my name is mayur'

# %%
str_z.count(' ')
# Out:
# 4

# %%
lst[4].count(' ')
# Out:
# 2

# %%
for item in lst:
    if item.count(' ') != 2:
        lst.remove(item)

# %%
lst
# Out:
# ['1 als as',
#  '2 I I',
#  '3 zijn his',
#  '4 dat that',
#  '5 hij he',
#  '6 was was',
#  '7 voor for',
#  '8 op on',
#  '9 zijn are',
#  '10 met with',
#  '11 ze they',
#  '12 zijn be',
#  '13 bij at',
#  '14 een one',
#  '15 hebben have',
#  '16 deze this',
#  '17 van from',
#  '18 door by',
#  '19 heet hot',
#  '20 woord word',
#  '21 maar but',
#  '22 wat what',
#  '23 sommige some',
#  '24 is is',
#  '25 het it',
#  '26 u you',
#  '27 of or',
#  '28 had had',
#  '29 de the',
#  '30 van of',
#  '31 aan to',
#  '32 en and',
#  '33 een a',
#  '34 in in',
#  '35 we we',
#  '36 kan can',
#  '37 uit out',
#  '38 andere other',
#  '39 waren were',
#  '40 die which',
#  '41 doen do',
#  '42 hun their',
#  '43 tijd time',
#  '44 indien if',
#  '45 zal will',
#  '46 hoe how',
#  '47 zei said',
#  '48 een an',
#  '49 elk each',
#  '50 vertellen tell',
#  '51 doet does',
#  '52 set set',
#  '53 drie three',
#  '54 willen want',
#  '55 lucht air',
#  '56 goed well',
#  '57 ook also',
# ...

# %%
len(lst)
# Out:
# 985

# %%
str_4 = ' '.join(lst)

# %%
str_4
# Out:
# '1 als as 2 I I 3 zijn his 4 dat that 5 hij he 6 was was 7 voor for 8 op on 9 zijn are 10 met with 11 ze they 12 zijn be 13 bij at 14 een one 15 hebben have 16 deze this 17 van from 18 door by 19 heet hot 20 woord word 21 maar but 22 wat what 23 sommige some 24 is is 25 het it 26 u you 27 of or 28 had had 29 de the 30 van of 31 aan to 32 en and 33 een a 34 in in 35 we we 36 kan can 37 uit out 38 andere other 39 waren were 40 die which 41 doen do 42 hun their 43 tijd time 44 indien if 45 zal will 46 hoe how 47 zei said 48 een an 49 elk each 50 vertellen tell 51 doet does 52 set set 53 drie three 54 willen want 55 lucht air 56 goed well 57 ook also 58 spelen play 59 klein small 60 end end 61 zetten put 62 thuis home 63 lezen read 65 poort port 66 grote large 67 spell spell 68 toevoegen add 69 zelfs even 70 land land 71 hier here 72 moet must 73 grote big 74 hoog high 75 dergelijke such 76 volgen follow 77 act act 78 waarom why 79 vragen ask 80 mannen men 81 verandering change 82 ging w
# ...

# %%
lst_4 = str_4.split(' ')

# %%
lst_4
# Out:
# ['1',
#  'als',
#  'as',
#  '2',
#  'I',
#  'I',
#  '3',
#  'zijn',
#  'his',
#  '4',
#  'dat',
#  'that',
#  '5',
#  'hij',
#  'he',
#  '6',
#  'was',
#  'was',
#  '7',
#  'voor',
#  'for',
#  '8',
#  'op',
#  'on',
#  '9',
#  'zijn',
#  'are',
#  '10',
#  'met',
#  'with',
#  '11',
#  'ze',
#  'they',
#  '12',
#  'zijn',
#  'be',
#  '13',
#  'bij',
#  'at',
#  '14',
#  'een',
#  'one',
#  '15',
#  'hebben',
#  'have',
#  '16',
#  'deze',
#  'this',
#  '17',
#  'van',
#  'from',
#  '18',
#  'door',
#  'by',
#  '19',
#  'heet',
#  'hot',
#  '20',
#  'woord',
#  'word',
#  '21',
#  'maar',
#  'but',
#  '22',
#  'wat',
#  'what',
#  '23',
#  'sommige',
#  'some',
#  '24',
#  'is',
#  'is',
#  '25',
#  'het',
#  'it',
#  '26',
#  'u',
#  'you',
#  '27',
#  'of',
#  'or',
#  '28',
#  'had',
#  'had',
#  '29',
#  'de',
#  'the',
#  '30',
#  'van',
#  'of',
#  '31',
#  'aan',
#  'to',
#  '32',
#  'en',
#  'and',
#  '33',
#  'een',
#  'a',
#  '34',
#  'in',
#  'in',
#  '35',
#  'we',
# ...

# %%
words_lst = []
for i in range(1, len(lst_4), 3):
    words_lst.append(lst_4[i])

# %%
words_lst
# Out:
# ['als',
#  'I',
#  'zijn',
#  'dat',
#  'hij',
#  'was',
#  'voor',
#  'op',
#  'zijn',
#  'met',
#  'ze',
#  'zijn',
#  'bij',
#  'een',
#  'hebben',
#  'deze',
#  'van',
#  'door',
#  'heet',
#  'woord',
#  'maar',
#  'wat',
#  'sommige',
#  'is',
#  'het',
#  'u',
#  'of',
#  'had',
#  'de',
#  'van',
#  'aan',
#  'en',
#  'een',
#  'in',
#  'we',
#  'kan',
#  'uit',
#  'andere',
#  'waren',
#  'die',
#  'doen',
#  'hun',
#  'tijd',
#  'indien',
#  'zal',
#  'hoe',
#  'zei',
#  'een',
#  'elk',
#  'vertellen',
#  'doet',
#  'set',
#  'drie',
#  'willen',
#  'lucht',
#  'goed',
#  'ook',
#  'spelen',
#  'klein',
#  'end',
#  'zetten',
#  'thuis',
#  'lezen',
#  'poort',
#  'grote',
#  'spell',
#  'toevoegen',
#  'zelfs',
#  'land',
#  'hier',
#  'moet',
#  'grote',
#  'hoog',
#  'dergelijke',
#  'volgen',
#  'act',
#  'waarom',
#  'vragen',
#  'mannen',
#  'verandering',
#  'ging',
#  'licht',
#  'soort',
#  'uitgeschakeld',
#  'huis',
#  'afbeelding',
#  'proberen',
#  'ons',
# ...

# %% [raw]
# open file
# read in string
# break string with \n
# then iterate through list so that to remove that strings inside list which contain more that 2 spaces
# again join this as string with ' '
# then split that string with ' '
# now iterate through this list by jumping with 3 elements
# and store these elements in separate another list
